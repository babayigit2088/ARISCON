# %% [markdown]
# I will clean the dataset, which is about second-hand car information from Ebay Kleinanzeigen. Then i will analyze this dataset and get some useful info. Let's start!..

# %%
import pandas as pd
import numpy as np

# %%
autos=pd.read_csv("C:\\Users\\babay\\autos.csv.zip",encoding="Latin-1")

# %%
autos
# Out:
#                 dateCrawled  \
# 0       2016-03-24 11:52:17
# 1       2016-03-24 10:58:45
# 2       2016-03-14 12:52:21
# 3       2016-03-17 16:54:04
# 4       2016-03-31 17:25:20
# 5       2016-04-04 17:36:23
# 6       2016-04-01 20:48:51
# 7       2016-03-21 18:54:38
# 8       2016-04-04 23:42:13
# 9       2016-03-17 10:53:50
# 10      2016-03-26 19:54:18
# 11      2016-04-07 10:06:22
# 12      2016-03-15 22:49:09
# 13      2016-03-21 21:37:40
# 14      2016-03-21 12:57:01
# 15      2016-03-11 21:39:15
# 16      2016-04-01 12:46:46
# 17      2016-03-20 10:25:19
# 18      2016-03-23 15:48:05
# 19      2016-04-01 22:55:47
# 20      2016-04-01 19:56:48
# 21      2016-03-27 11:38:00
# 22      2016-03-23 14:52:51
# 23      2016-03-12 19:43:07
# 24      2016-03-13 20:40:49
# 25      2016-03-18 21:44:09
# 26      2016-03-10 19:38:18
# 27      2016-03-07 12:51:23
# 28      2016-03-09 11:56:38
# 29      2016-03-08 19:55:19
# ...                     ...
# 371498  2016-03-11 15:50:38
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
# dateCrawled            371528 non-null object
# name                   371528 non-null object
# seller                 371528 non-null object
# offerType              371528 non-null object
# price                  371528 non-null int64
# abtest                 371528 non-null object
# vehicleType            333659 non-null object
# yearOfRegistration     371528 non-null int64
# gearbox                351319 non-null object
# powerPS                371528 non-null int64
# model                  351044 non-null object
# kilometer              371528 non-null int64
# monthOfRegistration    371528 non-null int64
# fuelType               338142 non-null object
# brand                  371528 non-null object
# notRepairedDamage      299468 non-null object
# dateCreated            371528 non-null object
# nrOfPictures           371528 non-null int64
# ...

# %%
autos.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# ...

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.columns=['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
       'vehicle_type', 'registration_year', 'gearbox', 'power_PS', 'model',
       'odometer', 'registration_month', 'fuel_type', 'brand',
       'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
       'last_seen']

# %%
autos.head(2)
# Out:
#           date_crawled                  name  seller offer_type  price abtest  \
# 0  2016-03-24 11:52:17            Golf_3_1.6  privat    Angebot    480   test
# 1  2016-03-24 10:58:45  A5_Sportback_2.7_Tdi  privat    Angebot  18300   test
#
#   vehicle_type  registration_year  gearbox  power_PS model  odometer  \
# 0          NaN               1993  manuell         0  golf    150000
# 1        coupe               2011  manuell       190   NaN    125000
#
#    registration_month fuel_type       brand unrepaired_damage  \
# 0                   0    benzin  volkswagen               NaN
# 1                   5    diesel        audi                ja
#
#             ad_created  nr_of_pictures  postal_code            last_seen
# 0  2016-03-24 00:00:00               0        70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00               0        66954  2016-04-07 01:46:50

# %% [markdown]
# We renamed the column's names, because they had some camelcase. And some column names could not be understood. But after replacement, we can easily understand, what is the column.

# %%
autos.describe()
# Out:
#               price  registration_year       power_PS       odometer  \
# count  3.715280e+05      371528.000000  371528.000000  371528.000000
# mean   1.729514e+04        2004.577997     115.549477  125618.688228
# std    3.587954e+06          92.866598     192.139578   40112.337051
# min    0.000000e+00        1000.000000       0.000000    5000.000000
# 25%    1.150000e+03        1999.000000      70.000000  125000.000000
# 50%    2.950000e+03        2003.000000     105.000000  150000.000000
# 75%    7.200000e+03        2008.000000     150.000000  150000.000000
# max    2.147484e+09        9999.000000   20000.000000  150000.000000
#
#        registration_month  nr_of_pictures   postal_code
# count       371528.000000        371528.0  371528.00000
# mean             5.734445             0.0   50820.66764
# std              3.712412             0.0   25799.08247
# min              0.000000             0.0    1067.00000
# 25%              3.000000             0.0   30459.00000
# ...

# %%
autos["nr_of_pictures"].value_counts()
# Out:
# 0    371528
# Name: nr_of_pictures, dtype: int64

# %% [markdown]
# --->The feature of "nr_of_pictures" has only one value. Because of that we can drop that.

# %%
autos.drop("nr_of_pictures",axis=1,inplace=True)

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 19 columns):
# date_crawled          371528 non-null object
# name                  371528 non-null object
# seller                371528 non-null object
# offer_type            371528 non-null object
# price                 371528 non-null int64
# abtest                371528 non-null object
# vehicle_type          333659 non-null object
# registration_year     371528 non-null int64
# gearbox               351319 non-null object
# power_PS              371528 non-null int64
# model                 351044 non-null object
# odometer              371528 non-null int64
# registration_month    371528 non-null int64
# fuel_type             338142 non-null object
# brand                 371528 non-null object
# unrepaired_damage     299468 non-null object
# ad_created            371528 non-null object
# postal_code           371528 non-null int64
# ...

# %% [markdown]
# --->The feature of "nr_of_pictures" has only one value. Because of that we can drop that.
# --->The feature of "offer_type" has two values. But gesuch has only three. Because of that we can drop that.

# %%
autos.rename({"odometer":"odometer_km"},axis=1,inplace=True)

# %%
autos.price.unique().shape
# Out:
# (5597,)

# %%
autos.price.describe().astype(int)
# Out:
# count        371528
# mean          17295
# std         3587953
# min               0
# 25%            1150
# 50%            2950
# 75%            7200
# max      2147483647
# Name: price, dtype: int32

# %%
autos.price.value_counts().sort_index(ascending=False).head(10)
# Out:
# 2147483647     1
# 99999999      15
# 99000000       1
# 74185296       1
# 32545461       1
# 27322222       1
# 14000500       1
# 12345678       9
# 11111111      10
# 10010011       1
# Name: price, dtype: int64

# %%
autos.price.value_counts().sort_index(ascending=False).tail(10)
# Out:
# 10       84
# 9         8
# 8         9
# 7         3
# 5        26
# 4         1
# 3         8
# 2        12
# 1      1189
# 0     10778
# Name: price, dtype: int64

# %% [markdown]
# For remove outliers, we can use area of 99.7% of this dataset. (mean+3*std)

# %%
autos=autos.loc[autos["price"].between(10,450000)]

# %%
autos.price.describe()
# Out:
# count    359388.000000
# mean       5929.146276
# std        9092.148012
# min          10.000000
# 25%        1250.000000
# 50%        3000.000000
# 75%        7499.000000
# max      445000.000000
# Name: price, dtype: float64

# %%
autos.odometer_km.value_counts().sort_index(ascending=False).head(10)
# Out:
# 150000    232236
# 125000     37307
# 100000     15429
# 90000      12338
# 80000      10888
# 70000       9659
# 60000       8586
# 50000       7526
# 40000       6315
# 30000       5927
# Name: odometer_km, dtype: int64

# %%
autos.odometer_km.describe().astype(int)
# Out:
# count    359388
# mean     125711
# std       39743
# min        5000
# 25%      125000
# 50%      150000
# 75%      150000
# max      150000
# Name: odometer_km, dtype: int32

# %% [markdown]
# ---> There is no outliers in feature of odometer_km.

# %%
autos[["date_crawled","ad_created","last_seen"]][:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-24 11:52:17  2016-03-24 00:00:00  2016-04-07 03:16:57
# 1  2016-03-24 10:58:45  2016-03-24 00:00:00  2016-04-07 01:46:50
# 2  2016-03-14 12:52:21  2016-03-14 00:00:00  2016-04-05 12:47:46
# 3  2016-03-17 16:54:04  2016-03-17 00:00:00  2016-03-17 17:40:17
# 4  2016-03-31 17:25:20  2016-03-31 00:00:00  2016-04-06 10:17:21

# %%
autos.ad_created.value_counts(normalize=True,dropna=False)
# Out:
# 2016-04-03 00:00:00    0.039039
# 2016-04-04 00:00:00    0.037748
# 2016-03-20 00:00:00    0.036462
# 2016-03-12 00:00:00    0.036120
# 2016-03-21 00:00:00    0.035755
# 2016-03-14 00:00:00    0.035274
# 2016-03-28 00:00:00    0.035124
# 2016-04-02 00:00:00    0.035018
# 2016-03-07 00:00:00    0.034484
# 2016-03-19 00:00:00    0.034294
# 2016-03-09 00:00:00    0.034175
# 2016-03-29 00:00:00    0.034155
# 2016-04-01 00:00:00    0.034011
# 2016-03-30 00:00:00    0.033443
# 2016-03-15 00:00:00    0.033351
# 2016-03-08 00:00:00    0.033346
# 2016-03-25 00:00:00    0.032831
# 2016-03-11 00:00:00    0.032817
# 2016-03-10 00:00:00    0.032508
# 2016-03-22 00:00:00    0.032149
# 2016-03-26 00:00:00    0.032105
# 2016-03-23 00:00:00    0.031957
# 2016-03-31 00:00:00    0.031949
# 2016-03-17 00:00:00    0.031250
# 2016-03-16 00:00:00    0.030424
# 2016-03-27 00:00:00    0.029987
# 2016-03-24 00:00:00    0.029940
# 2016-03-05 00:00:00    0.022892
# 2016-03-13 00:00:00    0.017060
# ...

# %%
autos.ad_created.sort_index()
# Out:
# 0         2016-03-24 00:00:00
# 1         2016-03-24 00:00:00
# 2         2016-03-14 00:00:00
# 3         2016-03-17 00:00:00
# 4         2016-03-31 00:00:00
# 5         2016-04-04 00:00:00
# 6         2016-04-01 00:00:00
# 8         2016-04-04 00:00:00
# 9         2016-03-17 00:00:00
# 10        2016-03-26 00:00:00
# 11        2016-04-07 00:00:00
# 12        2016-03-15 00:00:00
# 13        2016-03-21 00:00:00
# 14        2016-03-21 00:00:00
# 15        2016-03-11 00:00:00
# 16        2016-04-01 00:00:00
# 17        2016-03-20 00:00:00
# 18        2016-03-23 00:00:00
# 19        2016-04-01 00:00:00
# 20        2016-04-01 00:00:00
# 21        2016-03-27 00:00:00
# 22        2016-03-23 00:00:00
# 23        2016-03-12 00:00:00
# 24        2016-03-13 00:00:00
# 25        2016-03-18 00:00:00
# 26        2016-03-10 00:00:00
# 27        2016-03-07 00:00:00
# 28        2016-03-09 00:00:00
# 29        2016-03-08 00:00:00
# 30        2016-04-03 00:00:00
#                  ...
# ...

# %%
autos.registration_year.describe()
# Out:
# count    359388.000000
# mean       2004.419574
# std          79.958202
# min        1000.000000
# 25%        1999.000000
# 50%        2004.000000
# 75%        2008.000000
# max        9999.000000
# Name: registration_year, dtype: float64

# %%
autos.registration_year.value_counts().sort_index(ascending=False)
# Out:
# 9999    18
# 9450     1
# 9000     4
# 8888     2
# 8500     1
# 8200     1
# 8000     1
# 7800     1
# 7777     1
# 7500     1
# 7100     1
# 7000     4
# 6200     1
# 6000     6
# 5911     2
# 5900     1
# 5600     1
# 5555     2
# 5300     1
# 5000    16
# 4800     1
# 4500     2
# 4100     1
# 4000     3
# 3800     1
# 3700     1
# 3200     1
# 3000     5
# 2900     1
# 2800     1
#         ..
# 1940     2
# 1939     4
# 1938     8
# 1937    12
# 1936     7
# 1935     5
# 1934     4
# 1933     5
# 1932     4
# 1931     4
# 1930     4
# 1929     7
# 1928     2
# 1927     2
# 1925     1
# 1923     3
# 1911     1
# 1910    47
# 1800     4
# 1602     1
# 1600     2
# 1500     3
# 1400     1
# 1300     2
# 1255     1
# 1234     4
# 1111     1
# 1039     1
# 1001     1
# 1000    29
# Name: registration_year, Length: 144, dtype: int64

# %%
autos=autos[autos["registration_year"].between(1900,2018)]

# %%
autos.registration_year.value_counts().sort_index(ascending=False)
# Out:
# 2018     3799
# 2017     9947
# 2016     9154
# 2015     2889
# 2014     4765
# 2013     6115
# 2012     9354
# 2011    11989
# 2010    12263
# 2009    15487
# 2008    16021
# 2007    17480
# 2006    19987
# 2005    21648
# 2004    19441
# 2003    19572
# 2002    18782
# 2001    19686
# 2000    22939
# 1999    21941
# 1998    17152
# 1997    13972
# 1996    10369
# 1995     8894
# 1994     4626
# 1993     3275
# 1992     2884
# 1991     2650
# 1990     2468
# 1989     1250
#         ...
# 1952       11
# 1951       17
# 1950       18
# 1949        3
# 1948        3
# 1947        5
# 1946        2
# 1945        5
# 1944        2
# 1943        5
# 1942        2
# 1941        4
# 1940        2
# 1939        4
# 1938        8
# 1937       12
# 1936        7
# 1935        5
# 1934        4
# 1933        5
# 1932        4
# 1931        4
# 1930        4
# 1929        7
# 1928        2
# 1927        2
# 1925        1
# 1923        3
# 1911        1
# 1910       47
# ...

# %%
autos.shape
# Out:
# (359231, 19)

# %%
len(autos.brand.unique())
# Out:
# 40

# %%
autos.brand.unique()
# Out:
# array(['volkswagen', 'audi', 'jeep', 'skoda', 'bmw', 'peugeot', 'ford',
#        'mazda', 'nissan', 'renault', 'mercedes_benz', 'opel', 'seat',
#        'citroen', 'honda', 'fiat', 'mini', 'smart', 'hyundai',
#        'alfa_romeo', 'subaru', 'volvo', 'mitsubishi', 'kia', 'suzuki',
#        'lancia', 'porsche', 'sonstige_autos', 'toyota', 'chevrolet',
#        'dacia', 'daihatsu', 'trabant', 'chrysler', 'jaguar', 'daewoo',
#        'rover', 'saab', 'land_rover', 'lada'], dtype=object)

# %%
autos.brand.value_counts().sort_values(ascending=False)
# Out:
# volkswagen        76739
# bmw               38975
# opel              38552
# mercedes_benz     34491
# audi              31886
# ford              24767
# renault           17367
# peugeot           10777
# fiat               9335
# seat               6813
# skoda              5571
# mazda              5525
# smart              5164
# citroen            5037
# nissan             4894
# toyota             4616
# hyundai            3583
# mini               3354
# sonstige_autos     3313
# volvo              3231
# mitsubishi         2954
# honda              2725
# kia                2493
# suzuki             2274
# alfa_romeo         2247
# porsche            2156
# chevrolet          1789
# chrysler           1372
# dacia               889
# jeep                783
# daihatsu            774
# land_rover          758
# subaru              744
# jaguar              603
# daewoo              531
# saab                516
# trabant             490
# lancia              468
# ...

# %%
top_brands = autos["brand"].value_counts().index[:8]
top_brands
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford', 'renault',
#        'peugeot'],
#       dtype='object')

# %% [markdown]
# We can learn the average price of the top brands.

# %%
top_brands_mean_price = {} 
for brand in top_brands:
    brand_only = autos.loc[autos["brand"] == brand]
    mean_price = brand_only["price"].mean()
    top_brands_mean_price[brand] = int(mean_price)

# %%
top_brands_mean_price
# Out:
# {'volkswagen': 5339,
#  'bmw': 8406,
#  'opel': 2953,
#  'mercedes_benz': 8500,
#  'audi': 8990,
#  'ford': 3671,
#  'renault': 2414,
#  'peugeot': 3240}

# %%
top_brand_mileage_mean={}
for brand in top_brands:
    brand_only=autos.loc[autos["brand"]==brand]
    mean_mileage=brand_only["odometer_km"].mean()
    top_brand_mileage_mean[brand]=int(mean_mileage)

# %%
top_brand_mileage_mean
# Out:
# {'volkswagen': 128678,
#  'bmw': 132988,
#  'opel': 128963,
#  'mercedes_benz': 130771,
#  'audi': 129707,
#  'ford': 123928,
#  'renault': 128083,
#  'peugeot': 124877}

# %%
mean_price_series=pd.Series(top_brands_mean_price)

# %%
mean_price_series
# Out:
# volkswagen       5339
# bmw              8406
# opel             2953
# mercedes_benz    8500
# audi             8990
# ford             3671
# renault          2414
# peugeot          3240
# dtype: int64

# %%
mean_mileage_series=pd.Series(top_brand_mileage_mean)

# %%
mean_mileage_series
# Out:
# volkswagen       128678
# bmw              132988
# opel             128963
# mercedes_benz    130771
# audi             129707
# ford             123928
# renault          128083
# peugeot          124877
# dtype: int64

# %%
data_frame=pd.DataFrame(mean_price_series, columns=["mean_price"])
data_frame
# Out:
#                mean_price
# volkswagen           5339
# bmw                  8406
# opel                 2953
# mercedes_benz        8500
# audi                 8990
# ford                 3671
# renault              2414
# peugeot              3240

# %%
data_frame["mean_mileage"]=mean_mileage_series

# %%
data_frame
# Out:
#                mean_price  mean_mileage
# volkswagen           5339        128678
# bmw                  8406        132988
# opel                 2953        128963
# mercedes_benz        8500        130771
# audi                 8990        129707
# ford                 3671        123928
# renault              2414        128083
# peugeot              3240        124877

# %% [markdown]
# There is not a close relationship between price and mileage according to this dataframe.
