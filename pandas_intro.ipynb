# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # PANDAS

# %% [markdown]
# Pandas ile hap seklinde bilgiler,

# %% [markdown]
# Pandas nedir?
#      * Python' a ait acik kaynak kutuphanesi(open resource library)
#      * Data ile ugrasanlar icin guclu ve etkili bir arac

# %% [markdown]
# Pandas nerede kullanilir?
#      * Data analizinde,
#      * Data manipulation,
#      * Data gorsellestirmesi (visualization),

# %% [markdown]
# Avantajlari neler?
#     * Genis bir dokumantasyon,
#     * Devamli gelisiyor,
#     * Diger kutuphaneler ile uyumlu,
