# %%
from IPython.display import Image, display
display(Image(filename='ariscon.png', embed=True))

# %% [markdown]
# ## Pandas ile dosya okuma

# %%
from IPython.display import Image, display
display(Image(filename='file_types.png', embed=True))

# %% [markdown]
# ### .csv uzantili dosyalari okuma (comma seperated value)

# %%
from IPython.display import Image, display
display(Image(filename='example_csv.png', embed=True))

# %%
import pandas as pd

# %%
pd.read_csv('https://bit.ly/2UtyKOC')
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
columns = ['City', 'Color','Shape','State','Date']
df = pd.read_csv('https://bit.ly/2VeQAlO',header=None,names=columns,index_col='Date',skiprows=2)

# %%
df.head()
# Out:
#                                  City Color   Shape State
# Date
# 2/15/1931 14:00               Holyoke   NaN    OVAL    CO
# 6/1/1931 13:00                Abilene   NaN    DISK    KS
# 4/18/1933 19:00  New York Worlds Fair   NaN   LIGHT    NY
# 9/15/1934 15:30           Valley City   NaN    DISK    ND
# 6/15/1935 0:00            Crater Lake   NaN  CIRCLE    CA

# %% [markdown]
# ### .xlsx uzantili dosyalari okuma (excel)

# %%
pd.read_excel('Oscar.xlsx',sheet_name='English')
# Out:
#                    Name  Age Sex
# 0         Emil Jannings  44    M
# 1         Warner Baxter  41    M
# 2         George Arliss  62    M
# 3      Lionel Barrymore  53    M
# 4         Wallace Beery  47    M
# 5         Fredric March  35    M
# 6      Charles Laughton  34    M
# 7           Clark Gable  34    M
# 8       Victor McLaglen  49    M
# 9             Paul Muni  41    M
# 10        Spencer Tracy  37    M
# 11        Spencer Tracy  38    M
# 12         Robert Donat  34    M
# 13        James Stewart  32    M
# 14          Gary Cooper  40    M
# 15         James Cagney  43    M
# 16           Paul Lukas  48    M
# 17          Bing Crosby  41    M
# 18          Ray Milland  39    M
# 19        Fredric March  49    M
# 20        Ronald Colman  57    M
# 21     Laurence Olivier  41    M
# 22   Broderick Crawford  38    M
# 23          José Ferrer  39    M
# 24      Humphrey Bogart  52    M
# 25          Gary Cooper  51    M
# 26       William Holden  35    M
# ...
